# %%
python -c "from mamba_ssm.ops.selective_scan_interface import selective_scan_fn; print('✅ Mamba CUDA extensions working')"
# Out:
#   Cell In[1], line 1
#     python -c "from mamba_ssm.ops.selective_scan_interface import selective_scan_fn; print('✅ Mamba CUDA extensions working')"
#               ^
# SyntaxError: invalid syntax
