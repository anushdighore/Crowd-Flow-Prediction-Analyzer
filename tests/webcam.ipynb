# %%
import cv2

# Use the /video endpoint from the IP Webcam app
IP_WEB_CAM_URL = "http://192.168.137.154:8080/video"

# Open the video stream
cap = cv2.VideoCapture(IP_WEB_CAM_URL)

if not cap.isOpened():
    print("Error: Could not open video stream. Check the URL and network connection.")
    exit()

while True:
    ret, frame = cap.read()
    if not ret:
        print("Failed to grab frame")
        break

    # Display the frame
    cv2.imshow("IP Webcam Stream", frame)

    # Press 'q' to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against ABI version 0x1000009 but this version of numpy is 0x2000000
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import cv2
#       3 # Use the /video endpoint from the IP Webcam app
#       4 IP_WEB_CAM_URL = "http://192.168.137.154:8080/video"
#
# File c:\Users\anush\anaconda3\envs\crowdenv\lib\site-packages\cv2\__init__.py:8
#       5 import importlib
#       6 import sys
# ----> 8 from .cv2 import *
#       9 from .cv2 import _registerMatType
#      10 from . import mat_wrapper
#
# ImportError: numpy.core.multiarray failed to import

# %%
import cv2, numpy as np
print("OpenCV:", cv2.__version__)
print("NumPy:", np.__version__)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against ABI version 0x1000009 but this version of numpy is 0x2000000
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import cv2, numpy as np
#       2 print("OpenCV:", cv2.__version__)
#       3 print("NumPy:", np.__version__)
#
# File c:\Users\anush\anaconda3\envs\crowdenv\lib\site-packages\cv2\__init__.py:8
#       5 import importlib
#       6 import sys
# ----> 8 from .cv2 import *
#       9 from .cv2 import _registerMatType
#      10 from . import mat_wrapper
#
# ImportError: numpy.core.multiarray failed to import

# %%
import sys
print("Python:", sys.version)
import cv2
print("OpenCV:", cv2.__version__)
import numpy as np
print("NumPy:", np.__version__)
import pandas as pd
print("Pandas:", pd.__version__)
# Out:
# Python: 3.9.23 (main, Jun  5 2025, 13:25:08) [MSC v.1929 64 bit (AMD64)]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against ABI version 0x1000009 but this version of numpy is 0x2000000
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 3
#       1 import sys
#       2 print("Python:", sys.version)
# ----> 3 import cv2
#       4 print("OpenCV:", cv2.__version__)
#       5 import numpy as np
#
# File c:\Users\anush\anaconda3\envs\crowdenv\lib\site-packages\cv2\__init__.py:8
#       5 import importlib
#       6 import sys
# ----> 8 from .cv2 import *
#       9 from .cv2 import _registerMatType
#      10 from . import mat_wrapper
#
# ImportError: numpy.core.multiarray failed to import

# %%
# Check current package versions
# !pip list | findstr -i "numpy opencv"
# Out:
# numpy                   2.0.1

# %%
# Fix OpenCV-NumPy compatibility issue
# Uninstall conflicting packages
# !pip uninstall -y numpy opencv-python

# %%
# Install compatible versions
# !pip install numpy==1.24.3 opencv-python==4.8.1.78

# %%
# Install pandas if not already installed
# !pip install pandas

# %%
# Check Python version
import sys
print("Python version:", sys.version)
# Out:
# Python version: 3.9.23 (main, Jun  5 2025, 13:25:08) [MSC v.1929 64 bit (AMD64)]

# %%
# Check NumPy version (safe import)
try:
    import numpy as np
    print("NumPy version:", np.__version__)
except ImportError as e:
    print("NumPy import failed:", str(e))
# Out:
# NumPy version: 2.0.1

# %%
# Check OpenCV version (safe import)
try:
    import cv2
    print("OpenCV version:", cv2.__version__)
except ImportError as e:
    print("OpenCV import failed:", str(e))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against ABI version 0x1000009 but this version of numpy is 0x2000000
# OpenCV import failed: numpy.core.multiarray failed to import

# %%
# Check Pandas version (safe import)
try:
    import pandas as pd
    print("Pandas version:", pd.__version__)
except ImportError as e:
    print("Pandas import failed:", str(e))
# Out:
# Pandas import failed: No module named 'pandas'

# %%
# Check PyTorch and GPU availability
try:
    import torch
    print("PyTorch version:", torch.__version__)
    print("CUDA available:", torch.cuda.is_available())
    if torch.cuda.is_available():
        print("CUDA version:", torch.version.cuda)
        print("GPU Device:", torch.cuda.get_device_name(0))
        print("GPU Count:", torch.cuda.device_count())
    else:
        print("GPU: Not available (running on CPU)")
except ImportError as e:
    print("PyTorch import failed:", str(e))
# Out:
# PyTorch version: 2.5.1
# CUDA available: False
# GPU: Not available (running on CPU)

# %% [markdown]
# ## ⚠️ Problem Identified: CPU-Only PyTorch
#
# Your PyTorch 2.5.1 is the **CPU-only** version. You need the CUDA-enabled version to use your RTX 3050 GPU.
#
# ### Solution: Reinstall PyTorch with CUDA support
#
# Run the cells below to fix this.

# %%
import torch
print(f"PyTorch: {torch.__version__}")
print(f"CUDA Available: {torch.cuda.is_available()}")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import torch
#       2 print(f"PyTorch: {torch.__version__}")
#       3 print(f"CUDA Available: {torch.cuda.is_available()}")
#
# File c:\Users\anush\anaconda3\envs\crowdenv\lib\site-packages\torch\__init__.py:278
#     274                     raise err
#     276         kernel32.SetErrorMode(prev_error_mode)
# --> 278     _load_dll_libraries()
#     279     del _load_dll_libraries
#     282 def _get_cuda_dep_paths(path: str, lib_folder: str, lib_name: str) -> list[str]:
#     283     # Libraries can either be in path/nvidia/lib_folder/lib or path/lib_folder/lib
#
# File c:\Users\anush\anaconda3\envs\crowdenv\lib\site-packages\torch\__init__.py:261, in _load_dll_libraries()
#     257     err = ctypes.WinError(last_error)
#     258     err.strerror += (
# ...
